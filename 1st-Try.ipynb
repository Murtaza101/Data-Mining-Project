# %%
f = open("asd.txt", "r")
print(f.readline())
f.close()
# Out:
# {"created_at":"Sun Apr 14 10:30:09 +0000 2019","id":1117374475115356166,"id_str":"1117374475115356166","text":"RT @talhazahirkhan: The pseudo intellectuals should also know their Godfather USA also has a presidental system. By the way let the ppl dec\u2026","source":"\u003ca href=\"http:\/\/twitter.com\/download\/android\" rel=\"nofollow\"\u003eTwitter for Android\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":933371349321633792,"id_str":"933371349321633792","name":"ChaudhryPK","screen_name":"ChaudhryThinker","location":"Islamabad, Pakistan","url":null,"description":"\u200fA patriot Pakistani ,The colour of my \nblood is Green\n\n\n\u0645\u062c\u06be\u06d2 \u06c1\u06d2 \u062d\u06a9\u0645 \u0627\u0630\u0627\u06ba\u060c \u0644\u0627 \u0627\u0644\u06c1\u0670 \u0627\u0644\u0627 \u0627\u0644\u0644\u06c1\u200b","translator_type":"none","prot
# ...

# %%
f = open("asd.txt", "r")
for x in f:
  print(x)
# Out:
# {"created_at":"Sun Apr 14 10:30:09 +0000 2019","id":1117374475115356166,"id_str":"1117374475115356166","text":"RT @talhazahirkhan: The pseudo intellectuals should also know their Godfather USA also has a presidental system. By the way let the ppl dec\u2026","source":"\u003ca href=\"http:\/\/twitter.com\/download\/android\" rel=\"nofollow\"\u003eTwitter for Android\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":933371349321633792,"id_str":"933371349321633792","name":"ChaudhryPK","screen_name":"ChaudhryThinker","location":"Islamabad, Pakistan","url":null,"description":"\u200fA patriot Pakistani ,The colour of my \nblood is Green\n\n\n\u0645\u062c\u06be\u06d2 \u06c1\u06d2 \u062d\u06a9\u0645 \u0627\u0630\u0627\u06ba\u060c \u0644\u0627 \u0627\u0644\u06c1\u0670 \u0627\u0644\u0627 \u0627\u0644\u0644\u06c1\u200b","translator_type":"none","prot
# ...

# %%
from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer(r'\w+')
filterdText=tokenizer.tokenize(f)
print(filterdText)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-d69d876cbe79> in <module>
#       1 from nltk.tokenize import RegexpTokenizer
#       2 tokenizer = RegexpTokenizer(r'\w+')
# ----> 3 filterdText=tokenizer.tokenize(f)
#       4 print(filterdText)
#
# ~\Anaconda3\lib\site-packages\nltk\tokenize\regexp.py in tokenize(self, text)
#     134         # If our regexp matches tokens, use re.findall:
#     135         else:
# --> 136             return self._regexp.findall(text)
#     137
#     138     def span_tokenize(self, text):
#
# TypeError: expected string or bytes-like object

# %%
with open('asd.txt','r') as file:
    if file.mode == 'r':
        contents =file.read()
        print(contents)
# Out:
# {"created_at":"Sun Apr 14 10:30:09 +0000 2019","id":1117374475115356166,"id_str":"1117374475115356166","text":"RT @talhazahirkhan: The pseudo intellectuals should also know their Godfather USA also has a presidental system. By the way let the ppl dec\u2026","source":"\u003ca href=\"http:\/\/twitter.com\/download\/android\" rel=\"nofollow\"\u003eTwitter for Android\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":933371349321633792,"id_str":"933371349321633792","name":"ChaudhryPK","screen_name":"ChaudhryThinker","location":"Islamabad, Pakistan","url":null,"description":"\u200fA patriot Pakistani ,The colour of my \nblood is Green\n\n\n\u0645\u062c\u06be\u06d2 \u06c1\u06d2 \u062d\u06a9\u0645 \u0627\u0630\u0627\u06ba\u060c \u0644\u0627 \u0627\u0644\u06c1\u0670 \u0627\u0644\u0627 \u0627\u0644\u0644\u06c1\u200b","translator_type":"none","prot
# ...

# %%
from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer(r'\w+')
filterdText=tokenizer.tokenize(contents)
print(filterdText)
# Out:
# ['created_at', 'Sun', 'Apr', '14', '10', '30', '09', '0000', '2019', 'id', '1117374475115356166', 'id_str', '1117374475115356166', 'text', 'RT', 'talhazahirkhan', 'The', 'pseudo', 'intellectuals', 'should', 'also', 'know', 'their', 'Godfather', 'USA', 'also', 'has', 'a', 'presidental', 'system', 'By', 'the', 'way', 'let', 'the', 'ppl', 'dec', 'u2026', 'source', 'u003ca', 'href', 'http', 'twitter', 'com', 'download', 'android', 'rel', 'nofollow', 'u003eTwitter', 'for', 'Android', 'u003c', 'a', 'u003e', 'truncated', 'false', 'in_reply_to_status_id', 'null', 'in_reply_to_status_id_str', 'null', 'in_reply_to_user_id', 'null', 'in_reply_to_user_id_str', 'null', 'in_reply_to_screen_name', 'null', 'user', 'id', '933371349321633792', 'id_str', '933371349321633792', 'name', 'ChaudhryPK', 'screen_name', 'ChaudhryThinker', 'location', 'Islamabad', 'Pakistan', 'url', 'null', 'description', 'u200fA', 'patriot', 'Pakistani', 'The', 'colour', 'of', 'my', 'nblood', 'is', 'Green', 'n', 'n', 'n', 'u06
# ...

# %%
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\Usman\\Desktop\\Data Mining'

# %%
df = pd.read_json('asd.txt','r', lines=True)

# %%
df.head()
# Out:
#    contributors  coordinates          created_at display_text_range  \
# 0           NaN          NaN 2019-04-14 10:30:09                NaN
# 1           NaN          NaN 2019-04-14 10:30:09                NaN
# 2           NaN          NaN 2019-04-14 10:30:09                NaN
# 3           NaN          NaN 2019-04-14 10:30:11                NaN
# 4           NaN          NaN 2019-04-14 10:30:12                NaN
#
#                                             entities extended_entities  \
# 0  {'hashtags': [], 'urls': [], 'user_mentions': ...               NaN
# 1  {'hashtags': [], 'urls': [], 'user_mentions': ...               NaN
# 2  {'hashtags': [{'text': 'PresidentialSystem', '...               NaN
# 3  {'hashtags': [], 'urls': [], 'user_mentions': ...               NaN
# 4  {'hashtags': [{'text': 'PresidentialSystem', '...               NaN
#
#                                       extended_tweet  favorite_count  \
# ...

# %%
df.describe()
# Out:
#        contributors  coordinates  favorite_count  geo            id  \
# count           0.0          0.0           188.0  0.0  1.880000e+02
# mean            NaN          NaN             0.0  NaN  1.117376e+18
# std             NaN          NaN             0.0  NaN  7.554889e+11
# min             NaN          NaN             0.0  NaN  1.117374e+18
# 25%             NaN          NaN             0.0  NaN  1.117375e+18
# 50%             NaN          NaN             0.0  NaN  1.117376e+18
# 75%             NaN          NaN             0.0  NaN  1.117376e+18
# max             NaN          NaN             0.0  NaN  1.117377e+18
#
#              id_str  in_reply_to_status_id  in_reply_to_status_id_str  \
# count  1.880000e+02           1.200000e+01               1.200000e+01
# mean   1.117376e+18           1.117369e+18               1.117369e+18
# std    7.554889e+11           1.663627e+13               1.663627e+13
# min    1.117374e+18           1.117317e+18               1.117317e+18
# ...

# %%
df["text"]
# Out:
# 0      RT @talhazahirkhan: The pseudo intellectuals s...
# 1      RT @FarhanKVirk: اسلامی صدارتی نظام ہی وہ واحد...
# 2                                    #PresidentialSystem
# 3      RT @FarhanKVirk: بس انشااللہ ایک ہفتہ مزید سوش...
# 4      #PresidentialSystem\nصدارتی نظام کی خصوصیات\n\...
# 5      RT @iamhamzaabbasi: #PresidentialSystem A spec...
# 6      RT @iamhamzaabbasi: #PresidentialSystem A spec...
# 7      RT @Nimra_Ahmed__: @peaceforchange We need #pr...
# 8      RT @Haqeeqat_TV: عمران خان کی اپنی پارٹی کے اہ...
# 9      RT @Noshaba_Riyaz: @iamhamzaabbasi #Presidenti...
# 10     RT @_MM__22_: #PresidentialSystem\nApko kya pa...
# 11     RT @FarhanKVirk: یہ زردی مائل رنگ اس پارلیمانی...
# 12     RT @FarhanKVirk: یہ زردی مائل رنگ اس پارلیمانی...
# 13     RT @Haqeeqat_TV: عمران خان کی اپنی پارٹی کے اہ...
# 14     RT @Haqeeqat_TV: #PresidentialSystem وہ پودا ج...
# 15     RT @iamhamzaabbasi: #PresidentialSystem A spec...
# ...

# %%
df.columns
# Out:
# Index(['contributors', 'coordinates', 'created_at', 'display_text_range',
#        'entities', 'extended_entities', 'extended_tweet', 'favorite_count',
#        'favorited', 'filter_level', 'geo', 'id', 'id_str',
#        'in_reply_to_screen_name', 'in_reply_to_status_id',
#        'in_reply_to_status_id_str', 'in_reply_to_user_id',
#        'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'place',
#        'possibly_sensitive', 'quote_count', 'quoted_status',
#        'quoted_status_id', 'quoted_status_id_str', 'quoted_status_permalink',
#        'reply_count', 'retweet_count', 'retweeted', 'retweeted_status',
#        'source', 'text', 'timestamp_ms', 'truncated', 'user'],
#       dtype='object')

# %%
df1 = pd.DataFrame(df, columns= ['text','favorite_count','favourited','geo','retweet_count'])

# %%
df1
# Out:
#                                                   text  favorite_count  \
# 0    RT @talhazahirkhan: The pseudo intellectuals s...               0
# 1    RT @FarhanKVirk: اسلامی صدارتی نظام ہی وہ واحد...               0
# 2                                  #PresidentialSystem               0
# 3    RT @FarhanKVirk: بس انشااللہ ایک ہفتہ مزید سوش...               0
# 4    #PresidentialSystem\nصدارتی نظام کی خصوصیات\n\...               0
# 5    RT @iamhamzaabbasi: #PresidentialSystem A spec...               0
# 6    RT @iamhamzaabbasi: #PresidentialSystem A spec...               0
# 7    RT @Nimra_Ahmed__: @peaceforchange We need #pr...               0
# 8    RT @Haqeeqat_TV: عمران خان کی اپنی پارٹی کے اہ...               0
# 9    RT @Noshaba_Riyaz: @iamhamzaabbasi #Presidenti...               0
# 10   RT @_MM__22_: #PresidentialSystem\nApko kya pa...               0
# 11   RT @FarhanKVirk: یہ زردی مائل رنگ اس پارلیمانی...               0
# ...

# %%
pip install tweepy
# Out:
# The following command must be run outside of the IPython shell:
#
#     $ pip install tweepy
#
# The Python package manager (pip) can only be used from outside of IPython.
# Please reissue the `pip` command in a separate terminal or command prompt.
#
# See the Python documentation for more information on how to install packages:
#
#     https://docs.python.org/3/installing/

# %%
import tweepy
from textblob import TextBlob

# %%
consumer_key = 'ARdbnV7EjihSckz9QrwJzA5oi'
consumer_key_secret = 'ofmxa29BY96ujTpWC3AHEln2L07RIm0QoTkgPg9Skor5bNo09C'
access_token = '447757580-muXuDiJuiQ6ivbRFxMSTmedAujIikrvKEDPzILec'
access_token_secret = 'EKo7NyQ0dWe1D6TTyCZHEjahY95TQok2yqt04Mu4sb42i'

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_key_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
public_tweets = api.search('PresidentialSystem')

# %%
public_tweets = pd.DataFrame(df, columns= ['text'])
print(public_tweets)
# Out:
#                                                   text
# 0    RT @talhazahirkhan: The pseudo intellectuals s...
# 1    RT @FarhanKVirk: اسلامی صدارتی نظام ہی وہ واحد...
# 2                                  #PresidentialSystem
# 3    RT @FarhanKVirk: بس انشااللہ ایک ہفتہ مزید سوش...
# 4    #PresidentialSystem\nصدارتی نظام کی خصوصیات\n\...
# 5    RT @iamhamzaabbasi: #PresidentialSystem A spec...
# 6    RT @iamhamzaabbasi: #PresidentialSystem A spec...
# 7    RT @Nimra_Ahmed__: @peaceforchange We need #pr...
# 8    RT @Haqeeqat_TV: عمران خان کی اپنی پارٹی کے اہ...
# 9    RT @Noshaba_Riyaz: @iamhamzaabbasi #Presidenti...
# 10   RT @_MM__22_: #PresidentialSystem\nApko kya pa...
# 11   RT @FarhanKVirk: یہ زردی مائل رنگ اس پارلیمانی...
# 12   RT @FarhanKVirk: یہ زردی مائل رنگ اس پارلیمانی...
# 13   RT @Haqeeqat_TV: عمران خان کی اپنی پارٹی کے اہ...
# 14   RT @Haqeeqat_TV: #PresidentialSystem وہ پودا ج...
# 15   RT @iamhamzaabbasi: #PresidentialSystem A spec...
# ...

# %%
import re

# %%
for string in public_tweets: 
    for s in string:
        if re.match('@.+', string):
