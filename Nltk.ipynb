# %% [markdown]
# # Import Corpus Data

# %%
import nltk
nltk.download ()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %% [markdown]
# # checking Imported Data

# %%
from nltk.corpus import brown
brown.words()
# Out:
# ['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', ...]

# %% [markdown]
# # Tokennization (r'\w+') Only Text.
# "RegexpTokenizer" is a module of NLTK. It removes all the expression, symbol, character, numeric or any things whatever you want.
# The output is stored in the "filterdText" variable.

# %%
from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer(r'\w+')
filterdText=tokenizer.tokenize('Hello Guru99, You have build a very good site and I love visiting your site.')
print(filterdText)
# Out:
# ['Hello', 'Guru99', 'You', 'have', 'build', 'a', 'very', 'good', 'site', 'and', 'I', 'love', 'visiting', 'your', 'site']

# %% [markdown]
# ('\w+|\$[\d\.]+|\S+') text + symbols + numbers

# %%
from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer('\w+|$[\d.]+|\S+')
filterdText=tokenizer.tokenize('Hello Guru99, $$$$ You have build a very good site and I love visiting your site.')
print(filterdText)
# Out:
# ['Hello', 'Guru99', ',', '$$$$', 'You', 'have', 'build', 'a', 'very', 'good', 'site', 'and', 'I', 'love', 'visiting', 'your', 'site', '.']

# %% [markdown]
# # ('[A-Z]\w+')
# used for selecting word starting with capital letter

# %%
from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer('[A-Z]\w+')
filterdText=tokenizer.tokenize('Hello Guru99, $$$$ You have build a very good site and I love visiting your site.')
print(filterdText)
# Out:
# ['Hello', 'Guru99', 'You']

# %% [markdown]
# # Tokenize a text into a sequence of alphabetic and non-alphabetic characters, using the regexp \w+|[^\w\s]+.

# %%
from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer('\w+|[^\w\s]+')
filterdText=tokenizer.tokenize('Good muffins cost $3.88\n in New York.  Please buy me\ntwo of them.\n\nThanks.')
print(filterdText)
# Out:
# ['Good', 'muffins', 'cost', '$', '3', '.', '88', 'in', 'New', 'York', '.', 'Please', 'buy', 'me', 'two', 'of', 'them', '.', 'Thanks', '.']

# %% [markdown]
# # Code for word tokenization
# word_tokenize module is imported from the NLTK library.
# A variable "text" is initialized with two sentences.
# Text variable is passed in word_tokenize module and printed the result. This module breaks each word with punctuation which you can see in the output.

# %%
from nltk.tokenize import word_tokenize
text = "God is Great! I won a lottery."
print(word_tokenize(text))
# Out:
# ['God', 'is', 'Great', '!', 'I', 'won', 'a', 'lottery', '.']

# %% [markdown]
# # Sentence Tokenization
# In this program, imported the sent_tokenize module.
# We have taken the same sentence. Further sent module parsed that sentences and show output. It is clear that this function breaks each sentence.

# %%
from nltk.tokenize import sent_tokenize
text = "God is Great! I won a lottery."
print(sent_tokenize(text))
# Out:
# ['God is Great!', 'I won a lottery.']

# %% [markdown]
# # POS (Part-Of-Speech) Tagging & Chunking with NLTK
# Steps Involved:
#
# Tokenize text (word_tokenize)
# apply pos_tag to above step that is nltk.pos_tag(tokenize_text)

# %% [markdown]
# # Code for tokenization

# %%
from nltk import pos_tag
from nltk import RegexpParser
text ="learn php from guru99 and make study easy".split()
print("After Split:",text)
# Out:
# After Split: ['learn', 'php', 'from', 'guru99', 'and', 'make', 'study', 'easy']

# %% [markdown]
# # Code for POS

# %%
tokens_tag = pos_tag(text)
print("After Token:",tokens_tag)
# Out:
# After Token: [('learn', 'JJ'), ('php', 'NN'), ('from', 'IN'), ('guru99', 'NN'), ('and', 'CC'), ('make', 'VB'), ('study', 'NN'), ('easy', 'JJ')]

# %% [markdown]
# # Code for Chunk
# {<NN.?>*<VBD.?>*<JJ.?>*<CC>?}
# NN	noun, singular (cat, tree)
# VBD	verb past tense (pleaded)
# JJ	adjective (large)
# CC	coordinating conjunction

# %%
patterns= """mychunk:{<NN.?>*<VBD.?>*<IN.?>*<VB.?>*<JJ.?>*<CC>?}"""
chunker = RegexpParser(patterns)
print("After Regex:",chunker)
output = chunker.parse(tokens_tag)
print("After Chunking",output)
# Out:
# After Regex: chunk.RegexpParser with 1 stages:
# RegexpChunkParser with 1 rules:
#        <ChunkRule: '<NN.?>*<VBD.?>*<IN.?>*<VB.?>*<JJ.?>*<CC>?'>
# After Chunking (S
#   (mychunk learn/JJ)
#   (mychunk php/NN from/IN)
#   (mychunk guru99/NN and/CC)
#   (mychunk make/VB)
#   (mychunk study/NN easy/JJ))

# %% [markdown]
# # Use Case of Chunking
# Chunking is used for entity detection. An entity is that part of the sentence by which machine get the value for any intention
#
# Example:
# Temperature of New York.
# Here Temperature is the intention and New York is an entity.

# %% [markdown]
# # Code for Chunking

# %%
 import nltk
text = "learn php from guru99"
tokens = nltk.word_tokenize(text)
print(tokens)
tag = nltk.pos_tag(tokens)
print(tag)
grammar = "NP: {<DT>?<JJ>*<NN>}"
cp  =nltk.RegexpParser(grammar)
result = cp.parse(tag)
print(result)
result.draw()    # It will draw the pattern graphically which can be seen in Noun Phrase chunking
# Out:
# ['learn', 'php', 'from', 'guru99']
# [('learn', 'JJ'), ('php', 'NN'), ('from', 'IN'), ('guru99', 'NN')]
# (S (NP learn/JJ php/NN) from/IN (NP guru99/NN))

# %%
from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer('[A-Z]\w+')
filterdText=tokenizer.tokenize(r'C:\Users\Usman\Downloads\twitter.txt')
print(filterdText)
# Out:
# ['Users', 'Usman', 'Downloads']

# %%
with open(r'C:\Users\Usman\Downloads\twitter.txt','r') as file:
    if file.mode == 'r':
        contents =file.read()
        print(contents)
# Out:
# {"created_at":"Sat Apr 13 08:48:20 +0000 2019","id":1116986466817593344,"id_str":"1116986466817593344","text":"RT @chosen_rhytz: May nabasa ako that some fans of the other fandoms are ranting about how rude daw ung A-fans and A D N towards SC and CGM\u2026","source":"\u003ca href=\"http:\/\/twitter.com\" rel=\"nofollow\"\u003eTwitter Web Client\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":3533970074,"id_str":"3533970074","name":"dgr \u1d2c\u1d30\u1d3a","screen_name":"guiade25","location":null,"url":null,"description":null,"translator_type":"none","protected":false,"verified":false,"followers_count":79,"friends_count":77,"listed_count":1,"favourites_count":96927,"statuses_count":40686,"created_at":"Sat Sep 12 04:12:00 +0000 2015","utc_offset":null,"time_zone":null,"geo_enabled":false,"lang":"en","contributors_enabled":false,"is_transl
# ...

# %%
import pandas as pd

# %%
df = pd.read_json(r'C:\Users\Usman\Downloads\twitter.txt', lines=True)

# %%
df.head(5)
# Out:
#    contributors  coordinates          created_at display_text_range  \
# 0           NaN          NaN 2019-04-13 08:48:20                NaN
# 1           NaN          NaN 2019-04-13 08:48:21                NaN
# 2           NaN          NaN 2019-04-13 08:48:23                NaN
# 3           NaN          NaN 2019-04-13 08:48:24                NaN
# 4           NaN          NaN 2019-04-13 08:48:24                NaN
#
#                                             entities extended_entities  \
# 0  {'hashtags': [], 'urls': [], 'user_mentions': ...               NaN
# 1  {'hashtags': [], 'urls': [], 'user_mentions': ...               NaN
# 2  {'hashtags': [], 'urls': [], 'user_mentions': ...               NaN
# 3  {'hashtags': [], 'urls': [], 'user_mentions': ...               NaN
# 4  {'hashtags': [], 'urls': [], 'user_mentions': ...               NaN
#
#   extended_tweet  favorite_count  favorited filter_level  \
# 0            NaN               0      False          low
# ...

# %%
df["text"]
# Out:
# 0     RT @chosen_rhytz: May nabasa ako that some fan...
# 1     RT @ansabe_bts: GAGO GUYS IBA YUNG NGITI NI YO...
# 2     RT @FrPinillos: Wikileaks abre los ficheros k ...
# 3     pero firme q me sentí tan mal, no me daba pa l...
# 4     RT @censurometro: Julian Assange prometió que,...
# 5     RT @LoudreShippers: Good luck Team Marbel! #Lo...
# 6     RT @ANIABELLO_R: Lo que venimos diciendo hace ...
# 7     RT @porkyngtb: ibang iba yung laro nila today ...
# 8            GRABE LUNA, IBA KA 😭\n#BreakTheCeilingDLSU
# 9     Ang tagal naman ng bentosa marks na yan, magka...
# 10    RT @chavezjyrah: Day 7: Apey &amp; Andre’s Sec...
# 11    RT @Andresito_epi: Por el icono pensé que iba ...
# 12    Quedé con un par de amigos ayer y solo apareci...
# 13    Nakakasawa mamroblema ng iba puta kelan ko ba ...
# 14                                             MISMO!!!
# 15                                   wag kang bobo hA 🤫
# 16    hoyyy gusto ko era yun ang ibigay pero yung ib...
# ...

# %%
from nltk.tokenize import sent_tokenize

# %%
df2 
for line in df["text"]:
    df2.append(sent_tokenize(line))
# Out:
# ['RT @chosen_rhytz: May nabasa ako that some fans of the other fandoms are ranting about how rude daw ung A-fans and A D N towards SC and CGM…']
# ['RT @ansabe_bts: GAGO GUYS IBA YUNG NGITI NI YOONGI TALAGA DUN SA RAP PART NIYA HUHUHU NAPAKAGWAPO TAS LALIM NG BOSES JUSKO']
# ['RT @FrPinillos: Wikileaks abre los ficheros k tenían guardados tras la detención de Assange.', 'Assange prometió k si iba preso Wikileaks libe…']
# ['pero firme q me sentí tan mal, no me daba pa levantarme y tomarme un bondi q sentía q me iba a morir 😨']
# ['RT @censurometro: Julian Assange prometió que, si iba preso, Wikileaks liberaría cientos de miles de archivos con información clasificada d…']
# ['RT @LoudreShippers: Good luck Team Marbel!', '#LouDreAtKCCMalls https://t.co/wWNP6lzVOP']
# ['RT @ANIABELLO_R: Lo que venimos diciendo hace años.', 'Que ese acuerdo con las Farc iba a inundar el pais de coca.', 'Parecería que eso era lo qu…']
# ...

# %%
df1 = pd.DataFrame(df, columns= ['text'])

# %%
df1.to_json(r'C:\Users\Usman\Desktop\twit.txt')
